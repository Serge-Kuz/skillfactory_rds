# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from collections import Counter
print(os.listdir("../input"))
# Out:
# ['imbd-sf', 'UNICEF_stud_math']

# %%
data = pd.read_csv('../input/imbd-sf/data.csv')
data.head(5)
# Out:
#      imdb_id  popularity     budget     revenue                original_title  \
# 0  tt0369610   32.985763  150000000  1513528810                Jurassic World
# 1  tt1392190   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446   13.112507  110000000   295238201                     Insurgent
# 3  tt2488496   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# ...

# %%
len(data)
# Out:
# 1890

# %% [markdown]
# # Предобработка датасета

# %%
answer_ls = [] # создадим список с ответами. сюда будем добавлять ответы по мере прохождения теста
# сюда можем вписать создание новых колонок в датасете

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?
# Варианты ответов:
# 1. The Dark Knight Rises (tt1345836)
# 2. Spider-Man 3 (tt0413300)
# 3. Avengers: Age of Ultron (tt2395427)
# 4. The Warrior's Way	(tt1032751)
# 5. Pirates of the Caribbean: On Stranger Tides (tt1298650)

# %%
# тут вводим ваш ответ и добавлем в его список ответов (сейчас для примера стоит "1")
display(data[data['budget'] == max(data['budget']) ])

answer_ls.append(4)
# Out:
#        imdb_id  popularity     budget   revenue     original_title  \
# 491  tt1032751     0.25054  425000000  11087569  The Warrior's Way
#
#                                                   cast    director  \
# 491  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...  Sngmoo Lee
#
#                      tagline  \
# 491  Assassin. Hero. Legend.
#
#                                               overview  runtime  \
# 491  An Asian assassin (Dong-gun Jang) is forced to...      100
#
#                                         genres      production_companies  \
# 491  Adventure|Fantasy|Action|Western|Thriller  Boram Entertainment Inc.
#
#     release_date  vote_count  vote_average  release_year
# 491    12/2/2010          74           6.4          2010

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)
# 1. The Lord of the Rings: The Return of the King	(tt0167260)
# 2. Gods and Generals	(tt0279111)
# 3. King Kong	(tt0360717)
# 4. Pearl Harbor	(tt0213149)
# 5. Alexander	(tt0346491)

# %%
display(data.loc[data['runtime'].idxmax()])
answer_ls.append(2)
print("dd",data['runtime'].idxmax())
# Out:
# imdb_id                                                         tt0279111
# popularity                                                       0.469518
# budget                                                           56000000
# revenue                                                          12923936
# original_title                                          Gods and Generals
# cast                    Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...
# director                                                Ronald F. Maxwell
# tagline                               The nations heart was touched by...
# overview                The film centers mostly around the personal an...
# runtime                                                               214
# genres                                                  Drama|History|War
# production_companies                   Turner Pictures|Antietam Filmworks
# release_date                                                    2/21/2003
# ...

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)
# Варианты ответов:
#
# 1. Home on the Range	tt0299172
# 2. The Jungle Book 2	tt0283426
# 3. Winnie the Pooh	tt1449283
# 4. Corpse Bride	tt0121164
# 5. Hoodwinked!	tt0443536

# %%
display(data.loc[data['runtime'].idxmin()])
answer_ls.append(1)
# Out:
# imdb_id                                                         tt1449283
# popularity                                                        1.42534
# budget                                                           30000000
# revenue                                                          14460000
# original_title                                            Winnie the Pooh
# cast                    Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
# director                                        Stephen Anderson|Don Hall
# tagline                                                          Oh Pooh.
# overview                During an ordinary day in Hundred Acre Wood, W...
# runtime                                                                63
# genres                                                   Animation|Family
# production_companies    Walt Disney Pictures|Walt Disney Animation Stu...
# release_date                                                    4/13/2011
# ...

# %% [markdown]
# # 4. Средняя длительность фильма?
#
# Варианты ответов:
# 1. 115
# 2. 110
# 3. 105
# 4. 120
# 5. 100

# %%
display(data['runtime'].mean(skipna=True))
answer_ls.append(2)
# Out:
# 109.65343915343915

# %% [markdown]
# # 5. Средняя длительность фильма по медиане?
# Варианты ответов:
# 1. 106
# 2. 112
# 3. 101
# 4. 120
# 5. 115

# %%
display(data['runtime'].median(skipna=True))
answer_ls.append(1)
# Out:
# 106.5

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# Варианты ответов:
# 1. The Avengers	tt0848228
# 2. Minions	tt2293640
# 3. Star Wars: The Force Awakens	tt2488496
# 4. Furious 7	tt2820852
# 5. Avatar	tt0499549

# %%
data['profit'] = data.apply(lambda x: x['revenue'] - x['budget'], axis=1)
display(data.loc[data['profit'].idxmax()])
answer_ls.append(5)
# Out:
# imdb_id                                                         tt0499549
# popularity                                                        9.43277
# budget                                                          237000000
# revenue                                                        2781505847
# original_title                                                     Avatar
# cast                    Sam Worthington|Zoe Saldana|Sigourney Weaver|S...
# director                                                    James Cameron
# tagline                                       Enter the World of Pandora.
# overview                In the 22nd century, a paraplegic Marine is di...
# runtime                                                               162
# genres                           Action|Adventure|Fantasy|Science Fiction
# production_companies    Ingenious Film Partners|Twentieth Century Fox ...
# release_date                                                   12/10/2009
# ...

# %% [markdown]
# # 7. Какой фильм самый убыточный?
# Варианты ответов:
# 1. Supernova tt0134983
# 2. The Warrior's Way tt1032751
# 3. Flushed Away	tt0424095
# 4. The Adventures of Pluto Nash	tt0180052
# 5. The Lone Ranger	tt1210819

# %%
display(data.loc[data['profit'].idxmin()])
answer_ls.append(2)
# Out:
# imdb_id                                                         tt1032751
# popularity                                                        0.25054
# budget                                                          425000000
# revenue                                                          11087569
# original_title                                          The Warrior's Way
# cast                    Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...
# director                                                       Sngmoo Lee
# tagline                                           Assassin. Hero. Legend.
# overview                An Asian assassin (Dong-gun Jang) is forced to...
# runtime                                                               100
# genres                          Adventure|Fantasy|Action|Western|Thriller
# production_companies                             Boram Entertainment Inc.
# release_date                                                    12/2/2010
# ...

# %% [markdown]
# # 8. Сколько всего фильмов в прибыли?
# Варианты ответов:
# 1. 1478
# 2. 1520
# 3. 1241
# 4. 1135
# 5. 1398

# %%
display(len(data[data['profit']>0]))
answer_ls.append(1)
# Out:
# 1478

# %% [markdown]
# # 9. Самый прибыльный фильм в 2008 году?
# Варианты ответов:
# 1. Madagascar: Escape 2 Africa	tt0479952
# 2. Iron Man	tt0371746
# 3. Kung Fu Panda	tt0441773
# 4. The Dark Knight	tt0468569
# 5. Mamma Mia!	tt0795421

# %%
display(data[data['release_year'] ==2008 ].groupby('revenue').max().sort_values(by=['revenue'], ascending = False).head(1))
answer_ls.append(4)
# Out:
#               imdb_id  popularity     budget   original_title  \
# revenue
# 1001921825  tt0468569    8.466668  185000000  The Dark Knight
#
#                                                          cast  \
# revenue
# 1001921825  Christian Bale|Michael Caine|Heath Ledger|Aaro...
#
#                      director          tagline  \
# revenue
# 1001921825  Christopher Nolan  Why So Serious?
#
#                                                      overview  runtime  \
# revenue
# 1001921825  Batman raises the stakes in his war on crime. ...      152
#
#                                  genres  \
# revenue
# 1001921825  Drama|Action|Crime|Thriller
#
#                                          production_companies release_date  \
# revenue
# 1001921825  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
#
#             vote_count  vote_average  release_year     profit
# revenue
# 1001921825        8432           8.1          2008  816921825

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 (включительно)?
# Варианты ответов:
# 1. Winter's Tale	tt1837709
# 2. Stolen	tt1656186
# 3. Broken City	tt1235522
# 4. Upside Down	tt1374992
# 5. The Lone Ranger	tt1210819

# %%
# %%time
display(data[(data['release_year'].isin(range(2012,2014+1)))  & (data['profit'] <=0) ].groupby('profit').min().sort_values(by=['profit'], ascending = True).head(1))
answer_ls.append(5)
# Out:
#               imdb_id  popularity     budget   revenue   original_title  \
# profit
# -165710090  tt1210819     1.21451  255000000  89289910  The Lone Ranger
#
#                                                          cast        director  \
# profit
# -165710090  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                             tagline  \
# profit
# -165710090  Never Take Off the Mask
#
#                                                      overview  runtime  \
# profit
# -165710090  The Texas Rangers chase down a gang of outlaws...      149
#
#                               genres  \
# profit
# -165710090  Action|Adventure|Western
#
#                                          production_companies release_date  \
# profit
# -165710090  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#             vote_count  vote_average  release_year
# profit
# -165710090        1607           6.0          2013
# Wall time: 239 ms

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?
# Варианты ответов:
# 1. Action
# 2. Adventure
# 3. Drama
# 4. Comedy
# 5. Thriller

# %%
# %%time
genresListOfLists = [i for i in map(lambda x: x.split('|'), data['genres'])]
display(pd.Series([item for sublist in genresListOfLists for item in sublist]).value_counts().head(1)) #Wall time: 9 ms
#display(pd.Series([item for sublist in [i for i in map(lambda x: x.split('|'), data['genres'])] for item in sublist]).value_counts().head(1)) Wall time: 11 ms
#pd.Series([item for sublist in genresListOfLists for item in sublist]).value_counts().index.tolist()[0]
answer_ls.append(3)
# Out:
# Drama    782
# dtype: int64
# Wall time: 5 ms

# %% [markdown]
# # 12. Какого жанра среди прибыльных фильмов больше всего?
# Варианты ответов:
# 1. Drama
# 2. Comedy
# 3. Action
# 4. Thriller
# 5. Adventure

# %%
genresListOfListsInProfit = [i for i in map(lambda x: x.split('|'), data[data['profit']>0]['genres'])]
display(pd.Series([item for sublist in genresListOfListsInProfit for item in sublist]).value_counts().index.tolist()[0])
display(pd.Series(data.genres.str.split('|').sum()).value_counts().index[0])  #так тоже можно
answer_ls.append(1)
# Out:
# 'Drama'
# 'Drama'

# %% [markdown]
# # 13. Кто из режиссеров снял больше всего фильмов?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Ridley Scott
# 3. Steven Soderbergh
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
directorsListOfLists = [i for i in map(lambda x: x.split('|'), data['director'])]
display(pd.Series([item for sublist in directorsListOfLists for item in sublist]).value_counts().index.tolist()[0])
display(pd.Series(data.director.str.split('|').sum()).value_counts().index[0])#так тоже можно
answer_ls.append(3)
# Out:
# 'Steven Soderbergh'
# 'Steven Soderbergh'

# %% [markdown]
# # 14. Кто из режиссеров снял больше всего Прибыльных фильмов?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Clint Eastwood
# 3. Steven Spielberg
# 4. Ridley Scott
# 5. Christopher Nolan

# %%
directorsListOfListsInProfit = [i for i in map(lambda x: x.split('|'), data[data['profit']>0]['director'])]
display(pd.Series([item for sublist in directorsListOfListsInProfit for item in sublist]).value_counts().index.tolist()[0])
display(pd.Series(data['director'][data['profit'] >0].str.split('|').sum()).value_counts().index.tolist()[0])#так тоже можно
answer_ls.append(4)
# Out:
# 'Ridley Scott'
# 'Ridley Scott'

# %% [markdown]
# # 15. Кто из режиссеров принес больше всего прибыли?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Christopher Nolan
# 3. David Yates
# 4. James Cameron
# 5. Peter Jackson

# %%
display(data.groupby(['director'])['revenue'].aggregate('sum').sort_values(ascending=False).index[0]) #по сборам
display(data.groupby(['director'])['profit'].aggregate('sum').sort_values(ascending=False).index[0]) #по прибыли
answer_ls.append(5)
# Out:
# 'Peter Jackson'
# 'Peter Jackson'

# %% [markdown]
# # 16. Какой актер принес больше всего прибыли?
# Варианты ответов:
# 1. Emma Watson
# 2. Johnny Depp
# 3. Michelle Rodriguez
# 4. Orlando Bloom
# 5. Rupert Grint

# %%
#aa = ['Emma Watson','Johnny Depp', 'Michelle Rodriguez', 'Orlando Bloom']
actorsListOfLists = [i for i in map(lambda x: x.split('|'), data['cast'])]
aa=np.unique([item for sublist in actorsListOfLists for item in sublist])

resultDict ={}
for actor in aa:
    mask = [ actor in cast.split('|') for cast in data['cast'] ]
    profit = data.loc[mask]['profit'].sum()
    resultDict[actor] = profit
    #print(f"actor:{actor},\t profit:{profit}")
res = max(resultDict, key=resultDict.get)
print(f"\nWinnrer is {res}, with profit { resultDict[res]}")

answer_ls.append(1)
# Out:
# Winnrer is Emma Watson, with profit 6666245597

# %% [markdown]
# # 17. Какой актер принес меньше всего прибыли в 2012 году?
# Варианты ответов:
# 1. Nicolas Cage
# 2. Danny Huston
# 3. Kirsten Dunst
# 4. Jim Sturgess
# 5. Sami Gayle

# %%
#aa =   ['Nicolas Cage', 'Danny Huston', 'Kirsten Dunst', 'Jim Sturgess', 'Sami Gayle']
actorsListOfLists = [i for i in map(lambda x: x.split('|'), data['cast'])]
aa=np.unique([item for sublist in actorsListOfLists for item in sublist]) 
resultDict ={}

for actor in aa:
    
    mask = [ actor in cast.split('|') for cast in data['cast'] ]
    profit = data.loc[(mask) & (data.release_year == 2012)]['profit'].sum()
    
    resultDict[actor] = profit
    #print(f"actor:{actor},\t profit:{profit}")

res = min(resultDict, key=resultDict.get)
print(f"\nThe Looser is {res}, with profit { resultDict[res]}")
answer_ls.append(3)
# Out:
# The Looser is Kirsten Dunst, with profit -68109207

# %% [markdown]
# # 18. Какой актер снялся в большем количестве высокобюджетных фильмов? (в фильмах где бюджет выше среднего по данной выборке)
# Варианты ответов:
# 1. Tom Cruise
# 2. Mark Wahlberg
# 3. Matt Damon
# 4. Angelina Jolie
# 5. Adam Sandler

# %%
#aa = ['Tom Cruise', 'Mark Wahlberg', 'Matt Damon', 'Angelina Jolie', 'Adam Sandler']
actorsListOfLists = [i for i in map(lambda x: x.split('|'), data['cast'])]
aa=np.unique([item for sublist in actorsListOfLists for item in sublist])

resultDict ={}

meanBudget = data.budget.mean()
print(f"meanBudget = {meanBudget}")
for actor in aa:
    mask = [ actor in cast.split('|') for cast in data['cast'] ]
    movies = data.loc[(mask) & (data.budget > meanBudget)]['original_title'].count()
    #display( data.loc[(mask) & (data.budget > meanBudget)]['original_title'])
    resultDict[actor] = movies
    #print(f"actor:{actor},\t movies:{movies}")
    #print("-------------------------------------------")
res = max(resultDict, key=resultDict.get)
print(f"\nThe Winnrer is {res}, with  movies { resultDict[res]}")
answer_ls.append(3)
# Out:
# meanBudget = 54506961.474603176
#
# The Winnrer is Matt Damon, with  movies 18

# %% [markdown]
# # 19. В фильмах какого жанра больше всего снимался Nicolas Cage?
# Варианты ответа:
# 1. Drama
# 2. Action
# 3. Thriller
# 4. Adventure
# 5. Crime

# %%
mask = [ 'Nicolas Cage' in cast.split('|') for cast in data['cast'] ]

genresListOfLists4Nicolas = [i for i in map(lambda x: x.split('|'), data.loc[mask]['genres'])]
pre_result = pd.Series([item for sublist in genresListOfLists4Nicolas for item in sublist]).value_counts()
#https://stackoverflow.com/questions/952914/how-to-make-a-flat-list-out-of-list-of-lists
display(pre_result)
result = pre_result.index.tolist()[0]
print (f"-- {result} --")
answer_ls.append(2)
# Out:
# Action             17
# Thriller           15
# Drama              12
# Crime              10
# Fantasy             8
# Adventure           7
# Comedy              6
# Science Fiction     4
# Animation           3
# Mystery             3
# Family              3
# History             2
# Romance             1
# Horror              1
# War                 1
# dtype: int64
# -- Action --

# %% [markdown]
# # 20. Какая студия сняла больше всего фильмов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
prodcompListOfLists = [i for i in map(lambda x: x.split('|'), data['production_companies'])]
uniqueProdcompSorted=sorted(np.unique([item for sublist in prodcompListOfLists for item in sublist]))
resultDict={}
for prodcomp in uniqueProdcompSorted:
    mask = [prodcomp in production_companies.split('|') for production_companies in data['production_companies'] ]
    movies = data.loc[mask]['original_title'].count()
    resultDict[prodcomp] = movies
    #print(f"prodcomp:{prodcomp},\t movies:{movies}")
    #print("-------------------------------------------")
res = max(resultDict, key=resultDict.get)
print(f"\nThe Winnrer is {res}, with  movies { resultDict[res]}")
answer_ls.append(1)
# Out:
# The Winnrer is Universal Pictures, with  movies 173

# %% [markdown]
# # 21. Какая студия сняла больше всего фильмов в 2015 году?
# Варианты ответа:
# 1. Universal Pictures
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
prodcompListOfLists = [i for i in map(lambda x: x.split('|'), data['production_companies'])]
uniqueProdcompSorted=sorted(np.unique([item for sublist in prodcompListOfLists for item in sublist]))


resultDict={}
for prodcomp in uniqueProdcompSorted:
    mask = [prodcomp in production_companies.split('|') for production_companies in data['production_companies'] ]
    movies = data.loc[(mask) & (data.release_year == 2015)]['original_title'].count()
    resultDict[prodcomp] = movies
    #print(f"prodcomp:{prodcomp},\t movies:{movies}")
    #print("-------------------------------------------")
res = max(resultDict, key=resultDict.get)
print(f"\nThe Winnrer is {res}, with  movies { resultDict[res]}")
answer_ls.append(4)
# Out:
# The Winnrer is Warner Bros., with  movies 12

# %% [markdown]
# # 22. Какая студия заработала больше всего денег в жанре комедий за все время?
# Варианты ответа:
# 1. Warner Bros
# 2. Universal Pictures (Universal)
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Walt Disney

# %%
prodcompListOfLists = [i for i in map(lambda x: x.split('|'), data['production_companies'])]
uniqueProdcomp=[item for sublist in prodcompListOfLists for item in sublist]
comedyMask =  ['Comedy' in genres.split('|') for genres in data['genres'] ]

resultDict={}
for prodcomp in uniqueProdcomp:
    mask = [prodcomp in production_companies.split('|') for production_companies in data['production_companies'] ]
    mask1 = mask and comedyMask
    profit = data.loc[mask1 ]['profit'].sum()
    resultDict[prodcomp] = profit

res = max(resultDict, key=resultDict.get)
print(f"\nThe Winnrer is {res}, with  profit in Comedy { resultDict[res]}")
answer_ls.append(2)
# Out:
# The Winnrer is Universal Studios, with  profit in Comedy 59774752721

# %% [markdown]
# # 23. Какая студия заработала больше всего денег в 2012 году?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Lucasfilm

# %%
prodcompListOfLists = [i for i in map(lambda x: x.split('|'), data['production_companies'])]
uniqueProdcompSorted=sorted(np.unique([item for sublist in prodcompListOfLists for item in sublist]))


resultDict={}
for prodcomp in uniqueProdcompSorted:
    mask = [prodcomp in production_companies.split('|') for production_companies in data['production_companies'] ]
    profit = data.loc[(mask) & (data.release_year == 2012)]['profit'].sum()
    resultDict[prodcomp] = profit
    #print(f"prodcomp:{prodcomp},\t movies:{profit}")
    #print("-------------------------------------------")
res = max(resultDict, key=resultDict.get)
print(f"\nThe Winnrer is {res}, with  profit { resultDict[res]}")
answer_ls.append(3)
# Out:
# The Winnrer is Columbia Pictures, with  profit 2501406608

# %% [markdown]
# # 24. Самый убыточный фильм от Paramount Pictures
# Варианты ответа:
#
# 1. K-19: The Widowmaker tt0267626
# 2. Next tt0435705
# 3. Twisted tt0315297
# 4. The Love Guru tt0811138
# 5. The Fighter tt0964517

# %%
minProf = data[data['production_companies'].str.contains('Paramount Pictures')]['profit'].min()
display(data[data['profit'] == minProf][['original_title','imdb_id']])
answer_ls.append(1)
# Out:
#            original_title    imdb_id
# 926  K-19: The Widowmaker  tt0267626

# %% [markdown]
# # 25. Какой Самый прибыльный год (заработали больше всего)?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2002
# 5. 2015

# %%
display(data.groupby('release_year')['profit'].sum().idxmax())
answer_ls.append(5)
# Out:
# 2015

# %% [markdown]
# # 26. Какой Самый прибыльный год для студии Warner Bros?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2010
# 5. 2015

# %%
display(data[data['production_companies'].str.contains('Warner Bros')].groupby('release_year')['profit'].sum().idxmax())
answer_ls.append(1)
# Out:
# 2014

# %% [markdown]
# # 27. В каком месяце за все годы суммарно вышло больше всего фильмов?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
from datetime import datetime
data['release_month'] =data['release_date'].apply( lambda x: datetime.strptime(x,'%m/%d/%Y').month)
display(data.groupby('release_month')['imdb_id'].count().idxmax())
answer_ls.append(4)
# Out:
# 9

# %% [markdown]
# # 28. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)
# Варианты ответа:
# 1. 345
# 2. 450
# 3. 478
# 4. 523
# 5. 381

# %%
#display(data[(data['release_month'] >= 6) & (data['release_month'] <= 8)].groupby('release_month')['imdb_id'].count().sum())
summer = range(6,8+1)
display(data.query( 'release_month in @summer').groupby('release_month')['imdb_id'].count().sum())
answer_ls.append(2)
# Out:
# 450

# %% [markdown]
# # 29. Какой режисер выпускает (суммарно по годам) больше всего фильмов зимой?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Christopher Nolan
# 3. Clint Eastwood
# 4. Ridley Scott
# 5. Peter Jackson

# %%
winter = [1,2,12]
data['release_in_winter'] =data['release_date'].apply( lambda x: datetime.strptime(x,'%m/%d/%Y').month in winter)

directorsListOfListsInWinter = [i for i in map(lambda x: x.split('|'), data[data['release_in_winter']==True]['director'])]
display(pd.Series([item for sublist in directorsListOfListsInWinter for item in sublist]).value_counts().index.tolist()[0])
answer_ls.append(5)
# Out:
# 'Peter Jackson'

# %% [markdown]
# # 30. Какой месяц чаще всего по годам самый прибыльный?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
g = data.groupby(['release_year','release_month'] )['profit'].agg(['sum', 'count']).reset_index()

max_year = data.release_year.max()
min_year = data.release_year.min()
profitMonths=[]
for year in range(min_year, max_year+1 ):
    pos=g.query('release_year == @year')['sum'].idxmax()
    month = g.iloc[pos]['release_month']
    profitMonths.append(month)
print(f'month {pd.Series(profitMonths).value_counts().index[0]}, N- {pd.Series(profitMonths).value_counts().values[0]}')
answer_ls.append(2)
# Out:
# month 6, N- 7

# %% [markdown]
# # 31. Названия фильмов какой студии в среднем самые длинные по количеству символов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
data['original_title_lenght'] =  data['original_title'].apply( len)
prodcompListOfLists = [i for i in map(lambda x: x.split('|'), data['production_companies'])]
uniqueProdcompSorted=sorted(np.unique([item for sublist in prodcompListOfLists for item in sublist]))


resultDict={}
for prodcomp in uniqueProdcompSorted:
    mask = [prodcomp in production_companies.split('|') for production_companies in data['production_companies'] ]
    original_title_lenght = data.loc[mask]['original_title_lenght'].mean()
    resultDict[prodcomp] = original_title_lenght
    
    #print(f"prodcomp:{prodcomp},\t original_title_lenght:{original_title_lenght}")
    #print("-------------------------------------------")

res = max(resultDict, key=resultDict.get)
print(f"\nThe Winnrer is {res}, with  original_title_lenght { resultDict[res]}")
answer_ls.append(5)
# Out:
# The Winnrer is Four By Two Productions, with  original_title_lenght 83.0

# %% [markdown]
# # 32. Названия фильмов какой студии в среднем самые длинные по количеству слов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
data['original_title_words_count'] = data['original_title'].apply(lambda x: len(x.split()))
prodcompListOfLists = [i for i in map(lambda x: x.split('|'), data['production_companies'])]
uniqueProdcompSorted=sorted(np.unique([item for sublist in prodcompListOfLists for item in sublist]))


resultDict={}
for prodcomp in uniqueProdcompSorted:
    mask = [prodcomp in production_companies.split('|') for production_companies in data['production_companies'] ]
    original_title_words_count = data.loc[mask]['original_title_words_count'].mean()
    resultDict[prodcomp] = original_title_words_count
    
    #print(f"prodcomp:{prodcomp},\t original_title_lenght:{original_title_lenght}")
    #print("-------------------------------------------")

res = max(resultDict, key=resultDict.get)
print(f"\nThe Winnrer is {res}, with  original_title_words_count { resultDict[res]}")
answer_ls.append(5)
# Out:
# The Winnrer is Four By Two Productions, with  original_title_words_count 12.0

# %% [markdown]
# # 33. Сколько разных слов используется в названиях фильмов?(без учета регистра)
# Варианты ответа:
# 1. 6540
# 2. 1002
# 3. 2461
# 4. 28304
# 5. 3432

# %%
wordsInTitles=[]

l1=data['original_title'].apply(lambda x: x.lower().replace('  ',' ').split()) #replace("'",'').replace(',',' ').replace('¡','').

wordsInTitles.extend(l1.values)

uni=sorted(np.unique([item for sublist in wordsInTitles for item in sublist]))
print(len(uni))
answer_ls.append(3)
# Out:
# 2461

# %% [markdown]
# # 34. Какие фильмы входят в 1 процент лучших по рейтингу?
# Варианты ответа:
# 1. Inside Out, Gone Girl, 12 Years a Slave
# 2. BloodRayne, The Adventures of Rocky & Bullwinkle
# 3. The Lord of the Rings: The Return of the King
# 4. 300, Lucky Number Slevin

# %%
onepercfilms=data[data.vote_average > data.vote_average.quantile(.99)]['original_title'].reset_index()['original_title'].array
posib = [
 ['Inside Out', 'Gone Girl', '12 Years a Slave'],
 ['BloodRayne', 'The Adventures of Rocky and Bullwinkle'],
 ['The Lord of the Rings: The Return of the King', 'Upside Down'],
 ['300', 'Lucky Number Slevin'],
 ['Upside Down', '300', 'Inside Out', 'The Lord of the Rings: The Return of the King']]

result= "Nothing is found!"
for i in range(0,len(posib)):
    if all(elem in onepercfilms  for elem in posib[i]):
        result= '|'.join(posib[i]) 
        break  
print(result)
answer_ls.append(1)
# Out:
# Inside Out|Gone Girl|12 Years a Slave

# %% [markdown]
# # 35. Какие актеры чаще всего снимаются в одном фильме вместе
# Варианты ответа:
# 1. Johnny Depp & Helena Bonham Carter
# 2. Hugh Jackman & Ian McKellen
# 3. Vin Diesel & Paul Walker
# 4. Adam Sandler & Kevin James
# 5. Daniel Radcliffe & Rupert Grint

# %%
import itertools as itt

candidatesList=[('Johnny Depp','Helena Bonham Carter'),('Hugh Jackman', 'Ian McKellen'),('Vin Diesel', 'Paul Walker'),('Adam Sandler', 'Kevin James'),('Daniel Radcliffe','Rupert Grint')]
resListA=[]
resList=[]

actorsCombinationTupleByMovie = [i for i in map(lambda x: list(itt.combinations(sorted(x.split('|')),2)), data['cast'])]
actorsCombinationList=[item for sublist in actorsCombinationTupleByMovie for item in sublist]

df1=pd.DataFrame(pd.Series(actorsCombinationList).value_counts())
df1.columns=['FilmsCount']

display(df1.loc[candidatesList].sort_values(by='FilmsCount', ascending=False))
answer_ls.append(5)
# Out:
#                                      FilmsCount
# (Daniel Radcliffe, Rupert Grint)            8.0
# (Hugh Jackman, Ian McKellen)                5.0
# (Adam Sandler, Kevin James)                 5.0
# (Johnny Depp, Helena Bonham Carter)         NaN
# (Vin Diesel, Paul Walker)                   NaN

# %% [markdown]
# # 36. У какого из режиссеров выше вероятность выпустить фильм в прибыли? (5 баллов)101
# Варианты ответа:
# 1. Quentin Tarantino
# 2. Steven Soderbergh
# 3. Robert Rodriguez
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
directorsListOfLists = [i for i in map(lambda x: x.split('|'), data['director'])]
directorOneList = pd.Series([item for sublist in directorsListOfLists for item in sublist]).value_counts().index.tolist()
resultDict={}
#directorOneList=['Quentin Tarantino','Steven Soderbergh','Robert Rodriguez','Christopher Nolan','Clint Eastwood']

for directorOne in directorOneList:
    mask = [directorOne in director.split('|') for director in data['director'] ]
    directorFilm = data.loc[mask]
    resultDict[directorOne] = [directorFilm[directorFilm.profit > 0]['profit'].count()/directorFilm['profit'].count(), directorFilm[directorFilm.profit > 0]['profit'].count(), directorFilm['profit'].count()]
 

print ("100% успешных режиссеров",len({k: v for k, v in resultDict.items() if v[0] == 1}))
candidatesList=pd.Series( ['Quentin Tarantino','Steven Soderbergh','Robert Rodriguez','Christopher Nolan','Clint Eastwood']) # для быстрого анализа т.к. 100% успешных режиссеров 624чел. !

resList =  pd.DataFrame({ k: resultDict[k] for k in candidatesList }).T
resList.columns = ['Успешность','Фильмов в профите','Фильмов в всего']
display(resList.sort_values(by='Успешность', ascending=False))
answer_ls.append(4)
# Out:
# 100% успешных режиссеров 624
#                    Успешность  Фильмов в профите  Фильмов в всего
# Christopher Nolan    1.000000                8.0              8.0
# Quentin Tarantino    0.857143                6.0              7.0
# Clint Eastwood       0.833333               10.0             12.0
# Steven Soderbergh    0.769231               10.0             13.0
# Robert Rodriguez     0.727273                8.0             11.0

# %% [markdown]
# # Submission

# %%
len(answer_ls)
# Out:
# 36

# %%
pd.DataFrame({'Id':range(1,len(answer_ls)+1), 'Answer':answer_ls}, columns=['Id', 'Answer'])
# Out:
#     Id  Answer
# 0    1       4
# 1    2       2
# 2    3       1
# 3    4       2
# 4    5       1
# 5    6       5
# 6    7       2
# 7    8       1
# 8    9       4
# 9   10       5
# 10  11       3
# 11  12       1
# 12  13       3
# 13  14       4
# 14  15       5
# 15  16       1
# 16  17       3
# 17  18       3
# 18  19       2
# 19  20       1
# 20  21       4
# 21  22       2
# 22  23       3
# 23  24       1
# 24  25       5
# 25  26       1
# 26  27       4
# 27  28       2
# 28  29       5
# 29  30       2
# 30  31       5
# 31  32       5
# 32  33       3
# 33  34       1
# 34  35       5
# 35  36       4
